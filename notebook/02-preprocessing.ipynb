# %%
import numpy as np 
import pandas as pd

# %%
df = pd.read_csv("sales_forecasting_dataset.csv")

# %%
df.head(2)
# Out:
#          date  year  month  day  day_of_week  day_of_year  week_of_year  \
# 0  2010-01-01  2010      1    1            4            1            53
# 1  2010-01-02  2010      1    2            5            2            53
#
#    quarter  is_weekend  is_holiday  ...  temperature precipitation  \
# 0        1           0           1  ...        59.87          2.03
# 1        1           1           0  ...        57.54          3.61
#
#    gdp_growth unemployment_rate consumer_confidence  marketing_spend  \
# 0        2.22              6.08               62.38           616.92
# 1        2.68              5.89               65.68           782.26
#
#    website_visits  social_media_engagement  customer_footfall  sales
# 0            1335                      605                573  89.29
# 1            1337                      647                464  62.44
#
# [2 rows x 31 columns]
